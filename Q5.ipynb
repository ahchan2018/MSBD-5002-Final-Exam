# %% [markdown]
# # Scraping twitter using Selenium

# %%
#please make sure you have install chromedriver
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
browser = webdriver.Chrome()

query = u'transgene'
language = u'en'
url = u'https://twitter.com/search?vertical=default&q='+query+u'&l='+ language

browser.get(url)
time.sleep(1)

body = browser.find_element_by_tag_name('body')
for _ in range(100):
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.2)

tweets = browser.find_elements_by_class_name('tweet-text')


texts = []
for tweet in tweets:
    texts.append(tweet.text)

# %%
len(texts)
# Out:
# 173

# %%
texts
# Out:
# ['Landing pads for transgene insertion. A nice example here in tomato. ',
#  'The DFR locus: A smart landing pad for targeted transgene insertion in tomato (coll IJPB, SPS) | @scoopit https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0208395&utm_medium=social&utm_source=twitter …',
#  'The DFR locus: A smart landing pad for targeted transgene insertion in tomato (coll IJPB, SPS) | @scoopit',
#  'Nucleotide sequence and pharmaceutical composition based thereon with prolonged VEGF transgene expression ',
#  'Very happy to share our first paper on genome editing by CRISPR-Cas9. Deletion and reconstruction with targeted insertion of the DFR gene in tomato through HDR. The DFR locus: A smart landing pad for targeted transgene insertion in tomato http://dx.plos.org/10.1371/journal.pone.0208395 …',
#  'weirdly no, I think that the transgene is slowing down growth.',
#  'Fock state-based method for ultraluminous transgene',
#  '#Transgene Announces Upcoming #InvestorMeetings $TNG http://www.1stoncology.com/blog/transgene-announces-upcoming-investor-meetings …',
#  'Thank you for speaking up, Doctor. It is frustrating to see two movements - often the same people in both - fighting to restrict both pesticides and the transgene crops that could make them obsolete when so many lives depend on global food production.',
#  'Research – bioRxiv Pre-print – Use of MYB as a new synthetic activator to enhance transgene expression within repressed Polycomb chromatin https://hayneslabasu.wordpress.com/2018/12/05/research-biorxiv-pre-print-use-of-myb-as-a-new-synthetic-activator-to-enhance-transgene-expression-within-repressed-polycomb-chromatin/ …',
#  'Transgene $TNG.pa Announces Upcoming Investor Meetings',
#  '@TransgeneSA announces upcoming investor meetings.\nhttp://ow.ly/5lVc30mShJI ',
#  'B cells inhibit bone formation in #rheumatoidarthritis by suppressing osteoblast differentiation - in transgene mice; is this #RA?  #precisionMedicine #lifesciences #research https://go.nature.com/2Sqxnvy ',
#  '#tisagenlecleucel follow-up transgene levels do not appear to be associated with response or duration of response for #ALL or #DLBCL so are not currently reliable enough for clinical decisions relating to consolidation therapy including #BMT #ASH18',
#  'Waller presents data on qPCR for CAR transgene and B-cell aplasia in recipients of tisagenlecleucel; loss of detectable transgene not reliably predictive of relapse. Peak levels tend to be higher in responders as well, but lots of overlap in distributions.\n#ASH18 #cart',
#  'Very nice study by @ekwaller indicating that we cannot make decisions in management of #CARTcells patients by measuring transgene levels. Is this only true for Tisa? Will it apply to other constructs? #ASH18 pic.twitter.com/27bnCAzBkL',
#  '#ASH18 #leusm Waller: B cell lymphopoietic recovery might signify loss of functional CAR-T. Loss of transgene typically preceded ALL relapse, but some lost transgene and didn’t relapse. So there remain no good predictors of response duration at this point. ',
#  '#ASH18: Winship investigator Edmund K. Waller, MD, PhD, will speak on CAR transgene levels in ALL and DLBCL during an oral presentation in Room 6A at 5:30pm PST. More info: https://bit.ly/2rerh5Y ',
#  "Another $ASH18 Tweet to add: @Obsidian_Tx's gr8 poster on regulated CART constructs. Compelling data showing control of IL12 & IL15 via both bazedoxifene & trimethoprim: a well-exemplified in vivo platform for rheostat-like control of transgene cytokines to boost CART activity! ",
#  "How much consideration do you give the 5' UTR when expressing a transgene? \nLatest paper is now available here: https://rdcu.be/bcf2I \nThanks to the CHO group in @nicb_dcu , Prof Barron in @NIBRT_  and finally to @scienceirel for funding the work",
#  'A #non-integrative vector based #reprogramming approach: Generation of Transgene-Free Porcine Intermediate Type #Induced#PSCs @uni_copenhagen @TartuUniversity https://bit.ly/2AbCurU  pic.twitter.com/eTsV5XCOd5',
#  '#PLOSONE: The DFR locus: A smart landing pad for targeted transgene insertion in tomato http://dx.plos.org/10.1371/journal.pone.0208395 … @plosone',
#  'Thank you. The potential problem/issue I see will be unregulated CRISPR usage which will leave no trace of the CAS9 transgene after the mutation is made and then segregated out of the germplasm.',
#  '#ThrowbackThursday OPEN ACCESS: Methylation of chloroplast DNA does not affect viability and maternal inheritance in tobacco and may provide a strategy towards transgene containment ',
#  'Transgene Announces Upcoming Investor Meetings ',
#  'Use of MYB as a new synthetic activator to enhance transgene expression within repressed Polycomb chromatin #geneexpression #genome',
#  'Could TRANSGENE S.A. ORDINARY SHARES $TRGNF Change Direction After Less Shorts? -',
#  'Is Buying TRANSGENE S.A. ORDINARY SHARES $TRGNF, Having Lower Short Interest a Winning Strategy? -',
#  'Today TRANSGENE S.A. ORDINARY SHARES $TRGNF Reported Decrease in Shorted Shares',
#  'TRANSGENE S.A. ORDINARY SHARES $TRGNF Has Decline in Shorts -',
#  'Our last paper made it to the cover of #humangenetherapy. If you want to find out more about Dosage Thresholds and Influence of Transgene Cassette in Adeno-Associated Virus–Related Toxicity take a look. Special thanks @nicolas_torquet for the image #InstVisionParis',
#  'Transgene TNG TG4010 and PexaVec readouts to define 2019: Edison Investment Research Pharmaceutical & healthcare Transgene Latestage clinical trial readouts in 2019 will be critical to Transgene&rsquo;s immunoncology IO aspirations and if… http://bioportfol.io/QsThvq  #cancer',
#  '$TNG #Transgene S.A. Transgene - TG4010 and Pexa-Vec readouts to define 2019: Late-stage clinical trial readouts in 2019 will be critical to Transgene’s immunoncology (IO) aspirations and, if positive, could further its position in the sector; notably… http://dlvr.it/QsTJVz ',
#  'Use of MYB as a new synthetic activator to enhance transgene expression within repressed Polycomb chromatin  http://biorxiv.org/cgi/content/short/487736v1 … #bioRxiv',
#  'TRANSGENE S.A. ORDINARY SHARES $TRGNF Just Reported Decreased Shorts',
#  'Our split-QF paper is now on bioRXiv:\n "Split-QF system for fine-tuned transgene expression in Drosophila"\nAny feedback is very welcome! ',
#  '"We built an interactive cellular-resolution atlas of the zebrafish brain [6dpf] based on the reconstructions of over 2,000 individually GFP-labeled neurons ... Over a hundred transgene expression patterns (mainly Gal4 lines) ... co-registered with the single-neuron atlas." ',
#  'Check out the exclusive sneak peek of my manuscript describing the first single-neuron atlas of a vertebrate brain. https://bit.ly/2y0CStg  Research completed @mpiNeuro #neuroscience #brainatlas #neurons A big thank you…',
#  'NIAB is committed to #geneediting as a strategic tool in future wheat breeding programmes. Our researchers have shown that gene editing is efficient in wheat, with stable edited transgene-free wheat lines produced in 36 weeks https://bmcplantbiol.biomedcentral.com/articles/10.1186/s12870-018-1433-z … #crispr #bmcplantbiol',
#  '$SGMO has been granted #Patent September 25, 2018  Methods and compositions for genome engineering #AAV2_8\nmethods and compositions for insertion of transgene sequences encoding proteins that is aberrantly expressed in disease or disorder\n#genetherapy\nhttp://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&p=1&u=%2Fnetahtml%2FPTO%2Fsearch-bool.html&r=1&f=G&l=50&co1=AND&d=PTXT&s1=sangamo&OS=sangamo&RS=sangamo …',
#  'Bt transgene came from @MonsantoCo, which gave it away for free. Transgene introduced into locally preferred brinjal varieties by http://www.bari.gov.bd  govt agency, seeds given to farmers for free. Even if this was a publicity stunt by Monsanto, why keep this tech from farmers?',
#  '2/2 Incomprehensible to me how well-meaning people like @MartinHaeusling @peter_simone @ebner_sha @RenateKuenast can defend people who knowingly accept poisoning of Indian, Bangladeshi, Philippino farmers for ideological reasons #gmo…',
#  'Holger Puchta @KITKarlsruhe tells anecdote abt ideas of #gmo #crispr regulation: suggestion of politicians to discriminate nondiscriminatable edited mutations by additionally introduced #transgene as markers \n#geneditiert #synbio @cpsc_ucph @PlantSciDBG_en',
#  "A bit more history.. Post-transcriptional gene silencing by a transgene was first discovered in plants by Rich Jorgensen's lab in 1990 (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC159885/ …) and a lot of the groundwork to establish the RNAi phenomena was done also in plants in Sir David Baulcombe's lab @dcb40",
#  'A bit of history, RNAi was discovered @carnegiescience’s @CarnegieDevBio by Dr. Andy Fire when he was a Carnegie Staff Member, along with Dr. Craig Mello at UMass.   Gene-silencing technology gets first drug approval after 20-year wait https://www.nature.com/articles/d41586-018-05867-7 …',
#  'Zap your adult #zebrafish!\n@DMM_Journal: "Cancer modeling by Transgene Electroporation in Adult #Zebrafish (TEAZ)"\nhttp://dmm.biologists.org/content/early/2018/07/20/dmm.034561.article-info …\nLed by Scott Callahan @whitefishlab @sloan_kettering @studerl & colleagues, nice collab w/ our @aburger2009 @hlindsaych\n#zap @ZDMSociety',
#  'How can we use #CRISPR to engineer disease resistance in plants? @SyedShanZaidi @SMukhtarlab and Shahid Mansoor propose targeting susceptibility genes to produce disease-resistant yet transgene-free plants: http://bit.ly/2I1bFNO ',
#  'Fantastic trip to Canberra - seminars, workshops & showing how to do southern blots! Still necessary for validation of independent transgene insertions in rice unless u can sequence genome (had to borrow Colin’s box)  ',
#  'Using traditional breeding approaches, introducing disease resistance can take many years. This research utilizes CRISPR/Cas9 technology to produce transgene-free mildew-resistant tomato varieties in less than a year! #CRISPR\n\nhttps://www.nature.com/articles/s41598-017-00578-x …\n\nhttps://community.plantae.org/article/4955899029482374265/what-we-re-reading-april-13th …',
#  'Heather Whitney discusses gene editing machinery delivery with spray-on of nanomaterials (in planta biolistics). Maybe even transgene-free with RNPs in the future? Would be epic. #GARNetGE18',
#  'Our preprint on the effects of T-DNA insertions into Arabidopsis (epi)genome; deciphered using @nanopore and @bionanogenomics technology. @JoeEcker  w/ help from best undergrad student ever @acrivkin \n\nThe complex architecture of plant transgene insertions ',
#  'Stefan Grob @UZH_Science performed Hi-C.....and coincidently discovered why kanamycin resistance in @JoeEcker SALK lines is lost....transgene insertion can perturb 3D arrangement of the genome! Exciting result... ',
#  'Novel transgene stack confers resistance to powdery mildew in wheat in field trials #cropdisease',
#  'Detailed protocol for IV viral injections to drive systemic transgene expression - http://labrigger.com/blog/2018/01/12/detailed-protocol-for-iv-viral-injections-to-drive-systemic-transgene-expression/ …',
#  'Given the difficulty of keeping track of #GMO contamination, prevention is clearly better than cure. Farmers and community leaders must urgently learn from the communities studied in the new research and organize themselves to minimize the opportunities for transgene entry. ',
#  '#GMO genes are still getting into native Mexican maize http://gmwatch.org/en/news/latest-news/18032 … New study reveals how contamination occurs and gives pointers o how it might be avoided ',
#  'The journey of a (trans)gene - did you know over 300,000 plants can get evaluated in the field just to get a single transgene to market?  See the whole story at http://bit.ly/2AbEYpb ',
#  '“We observed no statistically significant increases in relative mutant frequency in the cII transgene or supF gene in the e-cig treated mouse or human cells, respectively.” https://www.ncbi.nlm.nih.gov/pubmed/29191599 ',
#  'This PM at #SfN17, our poster on "Cell-type-specific transgene expression in wild-type animals using endogenous proteins as scaffolds for assembling split transcription factors" (WW10). For those of you who like this sort of thing, it should be just the sort of thing you like.',
#  'Last one for the day. A stunning embryo. #SWSDB17\n\n48 Hours of Development, by Oscar Ruiz @intheOR in the Eisenhoffer Lab at @MDAndersonNews \n\nNote mosaicism of the green cells. They express a transgene that labels actin with GFP. ',
#  'https://www.nature.com/articles/s41477-017-0040-6 … GC-rich coding sequences reduce transposon-like, small RNA-mediated transgene silencing',
#  'How do you make C3 rice into productive C4 crop like maize, diverged 30M yrs ago? Slowly, one transgene at a time!\n\nhttp://www.cell.com/current-biology/fulltext/S0960-9822(17)31238-1 …',
#  '$SGMO been granted Patent 9777281 Oct3 #TALEN + #ZFN\nMethods and compositions for regulation of transgene expression\nhttp://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&p=1&u=%2Fnetahtml%2FPTO%2Fsearch-bool.html&r=1&f=G&l=50&co1=AND&d=PTXT&s1=sangamo&OS=sangamo&RS=sangamo …',
#  "' @servier Recruits #ViralVector Expert to Step Up its #CAR-T Technology #Transgene #Biotech  http://bit.ly/2stbDSd ",
#  'Transgene and Servier signed a deal to apply viral vectorization technology for allogenic CAR-T engineering. https://docs.google.com/spreadsheets/d/16joA-S8rzL5KjV_30e_qWw0ThE-8FJisO7w-_DQ0YHI/edit?usp=sharing …',
#  "Calif uses science to label Monsanto's Roundup a carcinogen, @neiltyson. There's more to #GMOs than one transgene. ",
#  '#CRISPR can be a GMO slayer, antis should embrace it! Cotton transgene for red fluorescence excised with precision!\n\nhttp://onlinelibrary.wiley.com/doi/10.1111/pbi.12755/full …',
#  'A disease resistance transgene from wheat confers resistance in barley: http://onlinelibrary.wiley.com/doi/10.1111/pbi.12765/abstract … Using a barley promoter improved outcomes.',
#  'Glyphosate and transgene effect on yield and mineral content of soybean http://onlinelibrary.wiley.com/doi/10.1002/ps.4625/abstract?campaign=wolacceptedarticle …',
#  'I realize we\'re all bored with reports of autocorrect hijinks, but "transgene" to "transgender" nearly derailed an important email just now.',
#  'Vrain, Huber and other anti-#GMO folks say adding a transgene makes a food unsafe. Tell that to the sweet potato! \n\nhttp://www.talkingbiotechpodcast.com/80-sweet-potato-natures-gmo/ …',
#  'Transgene presents very promising Immunology Data of its Next Generation Armed Oncolytic Virus http://biotech-365.com/transgene-presents-very-promising-new-immunology-data-of-its-next-generation-armed-oncolytic-virus-at-the-aacr-annual-meeting-in-washington-dc/ … #virus #immunology',
#  '@SciReports Rapid generation of a transgene-free powdery mildew resistant tomato by genome deletion. @KamounLab @PlantEvolution',
#  'Technical Advance - Transgene copy number measurement using dPCR http://tinyurl.com/lplckft ',
#  'Golden #bananas in field: elevated fruit pro-vitamin A from the expression of single banana transgene http://ow.ly/dhaW309TYRG  @PlantSciNews',
#  'GMO bananas are disease resistant, vitamin rich, all only banana genes, are sterile, + no risk of transgene escape \nhttp://www.mdpi.com/2071-1050/9/3/333/htm …',
#  'Fab feature about @spencerjenkins0 Greenwood Artist in our final issue. Pic of Transgene 3 Chair is by Diane Waby\nhttp://www.craftanddesign.net/magazine/250 ',
#  '#CRISPR editing Wheat by RNP  (Cas9 + cr & TrRNA) delivery -> no DNA = transgene free. Quite good performance http://www.nature.com/articles/ncomms14261 …',
#  '#zebrafish transgene nerds united! @BlockInTheBack #collaborate #sczi2017 #transgenics #win',
#  '#ASH16 Mueller: CAR transgene detectable >1yr in most pts. Flow or Q-PCR may be used to quantify CART persistence with high concordance. ',
#  'Quite amaizing! no transgene, no DNA needed, 0% off-target and true editing (not just mutation) #CRISPR',
#  'Genome editing in maize directed by CRISPR–Cas9 ribonucleoprotein complexes @NatureComms @scoopit http://sco.lt/858j9V ',
#  'Removing a gene segment to add a transgene - this is where the issue lies. \n#supportAgricNotGMO',
#  'Precision edits of a susceptibility gene produce transgene-free resistance to a plant virus: http://onlinelibrary.wiley.com/doi/10.1111/mpp.12417/full …',
#  'The MIP‐CreER transgene and tamoxifen-more caveats for the #betacell #diabetes mouse crowd http://physreports.physiology.org/content/4/18/e12863 … @PhysRep @MouseCentral',
#  'Update on Transgene after H116 results: Immuno-oncology combinations define strategy $TNG #PexaVec #TG4010',
#  'Efficient and transgene-free genome editing in wheat by transient expression of CRISPR/Cas9 http://www.nature.com/articles/ncomms12617 …',
#  "Pic with our ubi:switch #zebrafish transgene in the @nytimes from the Shubin lab's latest paper - congrats guys!",
#  'Congrats to @Andrew_Gehrke and @tetsuyanakamu whose work is on the Front Page of the @nytimes @NYTScience today! ',
#  'Highly efficient CRISPR/Cas9-mediated transgene knockin at the H11 locus in pigs #100topread http://www.nature.com/articles/srep14253 …',
#  'Interesting! Natural transgene may help plants #adapt to local conditions http://ow.ly/4nbPiW  v @AtlasOfScience',
#  'Not Transgene but Gene-Altered. Foods Coming To a Store Near You (Soon)  http://acsh.org/news/2016/04/22/crispr-edited-foods-coming-to-a-store-near-you-soon/ …',
#  'BRIEF-Transgene presents pre-clinical data on new generation oncolytic viral immunotherapy http://reut.rs/26cfVgN ',
#  "No transgene? No #GMO. USDA won't regulate #CRISPR deleted no-brown mushroom via @NatureNews http://buff.ly/1qWF538 ",
#  'Built-in biases have hindered our understanding of how transgene expression impacts the endogenous [host] gene" http://natureinstitute.org/txt/ch/nontarget.php … #GMO',
#  'Mind-controlled transgene expression by a wireless-powered optogenetic designer cell implant ',
#  'Our paper with transgene-free Cas9-induced targeted-mutagenesis in 2 crops is out http://www.genomebiology.com/2015/16/1/258   #CRISPR #plantsci #mouthfuloftech',
#  '$qure T-cell response to NaGLU transgene was persistent - immunosuppression was scaled back slowly',
#  'Plants with engineered DNA deletions but no remnant transgene: http://onlinelibrary.wiley.com/doi/10.1111/pbi.12201/abstract … Regulating genome editing gets complex very quickly.',
#  '.@kevinfolta: "We\'re literally bombarded by DNA on a daily basis. There\'s nothing about a transgene that makes it special." #AMAgmo',
#  'Natural transgene (from bacteria) aided colonization of land by plants: http://link.springer.com/article/10.1186%2F1745-6150-4-7 …',
#  '#Reproducibility: Differences in mouse transgene expression and effects in two different labs http://www.sciencedirect.com/science/article/pii/S1550413115003873 …',
#  '@Krisztab @rrellanalvarez If you can introduce a LUC transgene, we can image it. Someone at Salk is making a C elegans line for GLO-roots.',
#  'A Chinese study shows that an ampicillin resistance transgene was transferred from local engineered crops to soil bacteria #TalkingGMO',
#  '"Pest control & resistance mgmt thru release of insects carrying a male-selecting transgene" (Full article) #IPM',
#  '$BLUE flawless abstract. difficult to find fault with data so far. transgene expression obviously still on the increase.',
#  'Lack of pairing during meiosis triggers multigenerational transgene silencing in C…|Proc Natl Acad Sci U S A•Ahmed S http://pubmed.com/25941370 ',
#  'GM Transgene Corn Infiltrates South African Seed Supply http://naturalsociety.com/gm-transgene-corn-infiltrates-south-african-seed-supply/ … via @naturalsociety',
#  'Generating Customized Transgene Landing Sites and Multi-Transgene Arrays in Drosophila Using phiC31 Integrase. http://dlvr.it/8YtQd7 ',
#  'Sandeep Kumar @DowAgro | A Modular Gene Targeting System for Sequential Transgene Stacking in Plants at same genomic location #PAGXXIII',
#  'Imagine if those 21 conventionally bred corn lines were allowed to have a transgene to protect them from extremes or pests? #IQ2USLive',
#  'Fascinating!! Mind-controlled transgene expression by a wireless-powered optogenetic designer cell implant http://go.nature.com/PSXSKQ ',
#  '#Optogenetics: Mind-controlled gene switch to wirelessly program transgene expression in human cells http://bit.ly/1oKLFH4  #NBThighlight',
#  'Human brainwaves control transgene expression in mice via wireless optogenetic transplant http://bit.ly/1xIw2jr ',
#  'Mind blown by idea of mind-controlled transgene expression. Martin Fussenegger #FEBSEMBO2014',
#  'Epigenetic changes can cause cancer due to a transgene designed to attract methylation http://chrom.so/1o0OFIe ',
#  'Flower-visiting insects and their potential impact on transgene flow in rice http://ow.ly/yEBoN ',
#  'Transgene-free precise genome editing: the future of #biotech? Voytas and Gao discuss in @PLOSBiology\nhttp://www.ploscollections.org/article/info%3Adoi%2F10.1371%2Fjournal.pbio.1001877;jsessionid=4D92052C8307AE592906ED5753CFF8F2 …',
#  'As SEBI sleeps, Transgene Biotek hits upper and lower circuit on same day! \nhttp://www.moneylife.in/article/as-sebi-sleeps-transgene-biotek-hits-upper-and-lower-circuit-on-same-day/37466.html …\n@suchetadalal',
#  'Congratulations to Wusheng Liu for work related to plant transgene expressions on the cover of the Plant Biotechnology Journal',
#  'anyone got non-melanogaster Drosophila with a histone-GFP transgene (or any other FP)?',
#  'EuroBiotech: Britain fearful of Pfizer future, UCB on the hunt for antibody partners, Novartis snubs Transgene -- ',
#  'CMC exam. Transgene is a gene or genetic material that has been transferred naturally, or by any of a nº of genetic engineering techniques..',
#  'Transgene spread poses risk to the environment - new study http://www.biosafety-info.net/article.php?aid=1049 … #gmo',
#  "Patrick Moore thinks a #GMO can't be toxic if transgene taken from nontoxic source. Pure ignorance. http://mediasite.nbi.ac.uk/Mediasite/Play/25902ffd3e83440880f6554dd60bf3111d …",
#  '#Sanofi and French #Biotech Transgene start construction on state-of-the-art bioproduction unit in #Lyon http://bit.ly/MebixS ',
#  '@mbeisen @samimalkia Studycompares difft soybean varieties so cannot draw conclusions on effect of transgene. See: https://www.facebook.com/groups/GMOSF/permalink/337462046393052/ …',
#  '#ASH13 High: reviews difference betw gene addn (add transgene with a promoter) vs genome editing (put transgene into existng regulated site)',
#  '#gmo "A Built-In Strategy to Mitigate Transgene Spreading from Genetically Modified Corn" http://www.plosone.org/article/info%3Adoi%2F10.1371%2Fjournal.pone.0081645?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+plosone%2FPLoSONE+%28PLOS+ONE+Alerts%3A+New+Articles%29 … Awesome idea!',
#  'Study Critical of #GMO Corn Retracted. The only study that finds link with transgene corn & health risks is withdrawn http://www.takepart.com/article/2013/12/02/studying-linking-gmos-tumors-rats-retracted?cmpid=organic-share-twitter …',
#  'Transgene Escape: GMOs Spreading Uncontrollably Around the World. http://naturalsociety.com/gmos-spreading-uncontrollably-around-world/ … And something MUST be done to stop it!!',
#  'RT @NanaSilvergrim: Transgene Escape: GMOs Spreading Uncontrollably Around the World http://feedproxy.google.com/~r/naturalsocietyblog/~3/mUvvhGqhua8/ …',
#  'Transgene Escape: GMOs Spreading Uncontrollably Around the World http://feedproxy.google.com/~r/naturalsocietyblog/~3/mUvvhGqhua8/ …',
#  'Interactive "design your own transgene" lesson from University of Nebraska. Simple but effective.  http://cropwatch.unl.edu/web/biotechnology/biotechevents …',
#  'An inducible transgene expression system for zebrafish and chick - http://ow.ly/kwPzH ',
#  'Rapid construction of transgene-amplified CHO cell lines by cell cycle checkpoint engineering. http://1.usa.gov/11YxzAr  #A-T',
#  '#Sanofi SA and #Transgene SA Announce New Long-Term Joint Venture for Production of #Immunotherapy Treatments - http://ht.ly/jraA2 ',
#  '#NIH head Francis Collins & coll. on Use of microarray hybrid capture and #NGS to identify the anatomy of a #transgene: http://bit.ly/TLkHPb ',
#  '#GMtree Assessment of the salt tolerance and environmental biosafety of E. camaldulensis harboring a mangrin transgene \nhttp://link.springer.com/article/10.1007%2Fs10265-012-0503-9 …',
#  'Regulators Discover a Hidden Viral Gene in Commercial GMO Crops http://independentsciencenews.org/commentaries/regulators-discover-a-hidden-viral-gene-in-commercial-gmo-crops/ … Have you met Gene IV ? #inaug2013 #transgene #virus',
#  'Antibiotic resistance from #GMO s in microbes in rivers is just the tip of the iceberg of transgene escape ',
#  'Big Pharma Resistance Of America  \nGMO - GMO FOOD - GMO SEED - GMO Genocide - Transgene - Genetic Bomb \nStop UN... http://fb.me/1OwUQNRds ',
#  'Enhanced transgene expression from chromatinized plasmid #DNA in mouse liver versus naked DNA http://buff.ly/Tr4D25 ',
#  '#Nanotechnology may one day allow crop genetic engineering without transgene integration http://edition.pagesuite-professional.co.uk//launch.aspx?pbid=5e77f606-60e2-4fd9-9f38-92a132864061 … #science #GM p74',
#  '@r343l  You can cut acrylamide levels to 1/3 by using a transgene to suppress asparagine synthase. Another GM solution. http://www.ncbi.nlm.nih.gov/pubmed/18662372 ',
#  '@scio13 GFP transgene for all attendees! RT @kTraphagen: Can you say "Glow in the Dark" #scio13 ? [teaser]',
#  'Inducible Switch Controls Transgene Expression in #Viruses http://bit.ly/PcLXQg ',
#  '#lifescience #jobs Molecular Biology Group Leader Opening at Transgene, Hyderabad http://bit.ly/w0ebig ',
#  'Transgene giant Monsanto poisoned French farmer ',
#  '#Nano meets #GMO :  transgene delivery into triticale plants using the Agrobacterium T-DNA-derived nano-complex http://bit.ly/yzE2qa ',
#  '#Transgene Makes Moves to Fortify Presence in #China http://bit.ly/wctKId ',
#  'Check out this SlideShare presentation : Generation of Transgene-free iPSCs http://slidesha.re/uS5R5f ',
#  'No effect of transgene and strong wild parent effects on seed dormancy in crop–wild hybrids of rice #GMO  http://bit.ly/vVZazM ',
#  'Bayer CropScience and Precision BioSciences: Successful insertion of transgene into specific location in #cotton. http://tinyurl.com/6err3us ',
#  'I haz transgene MT @boffinus Cute kitteh transformed with GFP... aw! Scientists Produce Glow-in the-Dark Cats [Science] http://pulse.me/s/1CWbx ',
#  'Bruening: Taxonomically distant transgene presents lower risk of unintended outcomes than one from close source http://bit.ly/oFCBs1  #GMO',
#  'Combination therapy utilizing shRNA and an optimized resistant transgene for diseases caused by misfolded proteins http://bit.ly/rsrCVZ ',
#  'Hepatitis C;Therapeutic vaccine TG4040 (MVA-HCV)-Transgene announces Phase I clinical results http://goo.gl/fb/aiTWF ',
#  'Efficient generation of transgene-free human iPSCs by temperature-sensitive Sendai virus vectors (PNAS) http://bit.ly/nqRrvZ ',
#  '#Transgene and #Vivalis to Evaluate MVA #Vaccine Production in EB66 Duck Stem Cell Line http://bit.ly/r7xHk6',
#  'Transgene, ChronTech, and Inovio Partner to Take Prime-Boost #HCV Vaccination into Clinic http://bit.ly/eEuUDR',
#  'Roche pulls out of Transgene vaccine pact. http://bit.ly/g7frzk',
#  'Generation of transgene-free iPS cells from normal and neoplastic bone marrow and cord blood mononuclear cells http://bit.ly/eUwvtA',
#  'Beckman Coulter Developing NSCLC Companion Dx for Transgene:  \nread more\n       \n http://bit.ly/hOx2Zn',
#  'Christian Mosimann tells the story behind his paper (out today!) on ubiquitous transgene expression in zebrafish http://fb.me/NbWXGUA8',
#  'Lentiviral transfer of an inducible transgene expressing a soluble form of Gas1 causes glioma cell arrest, apoptos... http://bit.ly/cHuJUI',
#  'Expert says #Monsanto invested little in 2nd rate #GMO eggplant for India http://bit.ly/cxtWcp Could be called “transgene dumping”',
#  'TRANSGENE, Jennerex To Develop Anti-Cancer Virus; Could Earn Up To $116 Mln In Milestones: SAN FRANCISCO and ILLKI... http://bit.ly/b5Jh4B',
#  'Does anyone know about a transgenic capsicum / pepper that is used in Israel for de-desertification? (A transgene from a clam maybe?)',
#  'Eurocash. Riding on the success of Dendreon Transgene tests the appetite for cancer vaccines with proposed fundraising  http://bit.ly/colgNM',
#  'Conventional breeding causes more changes in plants than does the introduction of a single transgene. http://tinyurl.com/22ppwy9',
#  "Novartis gains option to license Transgene's cancer vaccine TG4010 http://bit.ly/9rsMND",
#  'Transgene from GM Corn Found in Soil-Dwelling Animals http://tinyurl.com/yjseoyb']

# %%
df = pd.DataFrame()
df['Contents'] = texts
df.head()
# Out:
#                                             Contents
# 0  Landing pads for transgene insertion. A nice e...
# 1  The DFR locus: A smart landing pad for targete...
# 2  The DFR locus: A smart landing pad for targete...
# 3  Nucleotide sequence and pharmaceutical composi...
# 4  Very happy to share our first paper on genome ...

# %% [markdown]
# # Build the model based on SentiWordNet(NLTK), word-list based(unsupervised)

# %%
from nltk.corpus import sentiwordnet as swn
from nltk import word_tokenize,pos_tag

def analyze_sentiment_sentiwordnet_lexicon(review, verbose=False):
    # tokenize and POS tag text tokens
    tokens = word_tokenize(review)
    tagged_text = pos_tag(tokens)

    pos_score = neg_score = token_count = obj_score = 0
    # get wordnet synsets based on POS tags
    # get sentiment scores if synsets are found
    for word, tag in tagged_text:
        ss_set = None
        if 'NN' in tag and list(swn.senti_synsets(word, 'n')):
            ss_set = list(swn.senti_synsets(word, 'n'))[0]
        elif 'VB' in tag and list(swn.senti_synsets(word, 'v')):
            ss_set = list(swn.senti_synsets(word, 'v'))[0]
        elif 'JJ' in tag and list(swn.senti_synsets(word, 'a')):
            ss_set = list(swn.senti_synsets(word, 'a'))[0]
        elif 'RB' in tag and list(swn.senti_synsets(word, 'r')):
            ss_set = list(swn.senti_synsets(word, 'r'))[0]
        # if senti-synset is found        
        if ss_set:
            # add scores for all found synsets
            pos_score += ss_set.pos_score()
            neg_score += ss_set.neg_score()
            obj_score += ss_set.obj_score()
            token_count += 1
    
    #final scores
    final_score = pos_score - neg_score
    norm_final_score = round(float(final_score) / token_count, 2)
    final_sentiment = 'positive' if norm_final_score >= 0 else 'negative'
    if verbose:
        norm_obj_score = round(float(obj_score) / token_count, 2)
        norm_pos_score = round(float(pos_score) / token_count, 2)
        norm_neg_score = round(float(neg_score) / token_count, 2)
        # to display results in a nice table
        sentiment_frame = pd.DataFrame([[final_sentiment, norm_obj_score, norm_pos_score, 
                                         norm_neg_score, norm_final_score]],
                                       columns=pd.MultiIndex(levels=[['SENTIMENT STATS:'], 
                                                             ['Predicted Sentiment', 'Objectivity',
                                                              'Positive', 'Negative', 'Overall']], 
                                                             labels=[[0,0,0,0,0],[0,1,2,3,4]]))
        #print(sentiment_frame)
        
    return final_sentiment

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords 
from nltk.tokenize import RegexpTokenizer
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Kenny\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kenny\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df['Results'] = df['Contents'].apply(analyze_sentiment_sentiwordnet_lexicon)

# %%
msk = df['Results']=='positive'
df['Results'][~msk] = 1
df['Results'][msk] = 0

# %%
df[0:100].to_csv('Q5_output.csv')
df.head(10)
# Out:
#                                             Contents Results
# 0  Landing pads for transgene insertion. A nice e...       0
# 1  The DFR locus: A smart landing pad for targete...       0
# 2  The DFR locus: A smart landing pad for targete...       0
# 3  Nucleotide sequence and pharmaceutical composi...       0
# 4  Very happy to share our first paper on genome ...       0
# 5  weirdly no, I think that the transgene is slow...       0
# 6  Fock state-based method for ultraluminous tran...       0
# 7  #Transgene Announces Upcoming #InvestorMeeting...       0
# 8  Thank you for speaking up, Doctor. It is frust...       1
# 9  Research – bioRxiv Pre-print – Use of MYB as a...       1
